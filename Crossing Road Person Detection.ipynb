# %% [markdown]
# ## CROSSING ROAD PERSON DETECTION
# ### We use Google Colaboratory to build YoloV8s model on our custom data

# %% [markdown]
# #### Step 1: Mounting Google Drive to Google Colaboratory

# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/
# Out:
# /gdrive/My Drive

# %% [markdown]
# ### Step 2: Install Ultralytics YOLOv8 package to run model

# %%
# !pip install ultralytics

# %% [markdown]
# ### Step 3: Unzip .zip file about our custom data

# %%
# !unzip dataset_2107.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_2905.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_295.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_305.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3370.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3375.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3405.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3445.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3480.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_35.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3540.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3560.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3575.txt
#   inflating: dataset_2107/labels/valid/6_VID_20210722_081_3645.txt
# ...

# %% [markdown]
# ### Step 4: Create .yaml file to makes model to our dataset

# %%
# %%writefile new_custom_data.yaml
# path: '../dataset_2107/'
# train: 'images/train'
# val: 'images/valid'

# # class names
# names:
#   0: 'crossing'

# # Hyperparameters ------------------------------------------------------------------------------------------------------
# # lr0: 0.01  # initial learning rate (i.e. SGD=1E-2, Adam=1E-3)
# # lrf: 0.01  # final learning rate (lr0 * lrf)
# # momentum: 0.937  # SGD momentum/Adam beta1
# # weight_decay: 0.0005  # optimizer weight decay 5e-4
# # warmup_epochs: 3.0  # warmup epochs (fractions ok)
# # warmup_momentum: 0.8  # warmup initial momentum
# # warmup_bias_lr: 0.1  # warmup initial bias lr
# # box: 7.5  # box loss gain
# # cls: 0.5  # cls loss gain (scale with pixels)
# # dfl: 1.5  # dfl loss gain
# # pose: 12.0  # pose loss gain
# # kobj: 1.0  # keypoint obj loss gain
# # label_smoothing: 0.5  # label smoothing (fraction)
# # nbs: 64  # nominal batch size
# # hsv_h: 0.015  # image HSV-Hue augmentation (fraction)
# # hsv_s: 0.7  # image HSV-Saturation augmentation (fraction)
# # hsv_v: 0.4  # image HSV-Value augmentation (fraction)
# # degrees: 0.0  # image rotation (+/- deg)
# # translate: 0.1  # image translation (+/- fraction)
# scale: 0.9  # image scale (+/- gain)
# # shear: 0.0  # image shear (+/- deg) from -0.5 to 0.5
# # perspective: 0.1  # image perspective (+/- fraction), range 0-0.001
# # flipud: 0.0  # image flip up-down (probability)
# # fliplr: 0.5  # image flip left-right (probability)
# # mosaic: 1.0  # image mosaic (probability)
# mixup: 1.0  # image mixup (probability)
# # copy_paste: 0.5  # segment copy-paste (probability)
# Out:
# Writing new_custom_data.yaml

# %% [markdown]
# ### Step 5: Training YOLOv8s model from our dataset

# %%
# !yolo task=detect mode=train model=yolov8s.pt imgsz=480 data=./new_custom_data.yaml epochs=10 batch=64 name=yolov8s_new cos_lr=True
# Out:
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Step 6: Test model from our YOLOv8s model

# %% [markdown]
# #### Conditon 1: Test on DEFAULT mode

# %%
# !yolo task=detect mode=predict model=best.pt source='20230705_071613000_iOS 1.mov' show=True imgsz=480 name=yolov8s
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 1 crossing, 63.4ms
# video 1/1 (2/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 1 crossing, 10.2ms
# video 1/1 (3/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 10.0ms
# video 1/1 (4/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 9.5ms
# video 1/1 (5/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 9.3ms
# video 1/1 (6/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 9.6ms
# video 1/1 (7/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 9.7ms
# ...

# %% [markdown]
# #### Conditon 2: Test on TRACKING mode

# %%
# !yolo task=detect mode=track model=new_best_yolov8.pt source='20230705_071613000_iOS 1.mov' imgsz=480 show
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 14.1 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.2s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.216 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 62.3ms
# video 1/1 (2/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 9.3ms
# video 1/1 (3/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 9.6ms
# video 1/1 (4/669) /gdrive/MyDrive/20230705_071613000_iOS 1.mov: 288x480 (no detections), 9.8ms
# ...
